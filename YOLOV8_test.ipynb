# %% [markdown]
# Test of yolo V8, based on this github article https://github.com/roboflow/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
import torch
from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.2.100  Python-3.10.11 torch-2.4.1+cu118 CUDA:0 (Quadro T1000 with Max-Q Design, 4096MiB)
# Setup complete  (12 CPUs, 15.8 GB RAM, 436.3/471.6 GB disk)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 display.clear_output()
#
# AttributeError: 'function' object has no attribute 'clear_output'

# %%
model = YOLO('yolov8n.pt')
dict_classes = model.model.names

# %%
#roles to detect:
#player
#ball
#goalkeeper
#referee
#nc =4

# %%
torch.cuda.is_available()
# Out:
# True

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.100  Python-3.10.11 torch-2.4.1+cu118 CUDA:0 (Quadro T1000 with Max-Q Design, 4096MiB)
# Setup complete  (12 CPUs, 15.8 GB RAM, 415.0/471.6 GB disk)

# %%
#!yolo task=detect mode=train model=yolov8n.pt data=C:/Studie/BEP/BEP_Football_tracking/yolo_data_format/data.yaml epochs=1 imgsz=608 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.18 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.100 ðŸš€ Python-3.10.11 torch-2.4.1+cu118 CUDA:0 (Quadro T1000 with Max-Q Design, 4096MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="G:/My Drive/BEP_football_tracking/yolo_data_format/data.yaml" epochs=1 imgsz=608 plots=True
