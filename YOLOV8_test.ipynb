# %% [markdown]
# This notebook serves as a template that will be used for testing of the various YOLO models. A very small subset of the data(80 train images, 20 test) is used to train and test on to test for any complications.

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
import torch
from IPython.display import display, Image
# Out:
# Ultralytics 8.3.49  Python-3.10.11 torch-2.4.1+cu118 CUDA:0 (Quadro T1000 with Max-Q Design, 4096MiB)
# Setup complete  (12 CPUs, 15.8 GB RAM, 392.4/471.6 GB disk)

# %%
torch.cuda.is_available()
# Out:
# True

# %%
model = YOLO("C:/Studie/BEP/BEP_Football_tracking/YOLO_results/players9/best.pt")

# %%
# Run inference on 'bus.jpg' with arguments
model.predict("C:/Studie/BEP/BEP_Football_tracking/sample_nl_match.mp4", save=True, imgsz=640, conf=0.25, show=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/727) C:\Studie\BEP\BEP_Football_tracking\sample_nl_match.mp4: 384x640 11 players, 6 goalkeeperss, 96.4ms
# video 1/1 (frame 2/727) C:\Studie\BEP\BEP_Football_tracking\sample_nl_match.mp4: 384x640 14 players, 7 goalkeeperss, 45.1ms
# video 1/1 (frame 3/727) C:\Studie\BEP\BEP_Football_tracking\sample_nl_match.mp4: 384x640 12 players, 6 goalkeeperss, 45.9ms
# ...

# %%
metrics = model.val(data="C:/Studie/BEP/BEP_Football_tracking/prototest_dataset/data.yaml", split = "test")
print(metrics)
# Out:
# Ultralytics YOLOv8.2.100  Python-3.10.11 torch-2.4.1+cu118 CUDA:0 (Quadro T1000 with Max-Q Design, 4096MiB)
# Model summary (fused): 168 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Studie\BEP\BEP_Football_tracking\prototest_dataset\labels\test... 10 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<00:00, 345.60it/s]
# val: New cache created: C:\Studie\BEP\BEP_Football_tracking\prototest_dataset\labels\test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:07<00:00,  4.00s/it]
#                    all         10        200    0.00184     0.0118   0.000967   0.000228
#                   ball         10         10          0          0          0          0
#                 player         10        170    0.00735     0.0471    0.00387   0.000913
#                referee         10         10          0          0          0          0
# ...
